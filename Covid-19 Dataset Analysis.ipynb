# %%
import pandas as pd

# %%
data=pd.read_csv(r"E:\Machine learning\4. covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(data.isnull())      # white color is indicating the null values
plt.show()

# %%
# Q-1) SHOW THE NUMBERS OF CONFIRMED,DEATHS AND RECOVERED CASES IN EACH REGION

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=True)
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Papua New Guinea               8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# <ipython-input-25-20fd7b835859>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
# Q-2) REMOVE ALL THE CASES WHERE CONFIRMED CASES ARE LESS THAN 10

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.Confirmed<10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[data.Confirmed<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data[~(data.Confirmed<10)]    # removing the required data sets
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data    # but still the data is same.. so we have to write  -        data=data[~(data.Confirmed<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data=data[~(data.Confirmed<10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
# Q-3) IN WHICH REGION, MAXIMUM NUMBERS OF CONFIRMED CASES WERE RECORDED?

# %%
df=pd.read_csv(r"E:\Machine learning\4. covid_19_data.csv")  # since we have changed the previous dataframe

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
# Q-4) IN WHICH REGION,MINIMUM NUMBRES OF DEATH WERE RECORDED?

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(30)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %%
# Q-5) HOW MANY CONFIRMED,DEATHS AND RECOVERED CASES WERE REPORTED IN INDIA TILL 29TH APRIL,2020?

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df['Region']=='India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Region, Length: 321, dtype: bool

# %%
df[df['Region']=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
df[df['Region']=='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
# Q-6) SORT THE ENTIRE DATA WRT CONFIRMED CASES IN ASCENDING ORDER

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df.sort_values(by=['Confirmed'])
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %%
df.sort_values(by=['Confirmed'],ascending=False)
# Out:
#           Date                         State          Region  Confirmed  \
# 265  4/29/2020                      New York              US     299691
# 153  4/29/2020                           NaN           Spain     236899
# 80   4/29/2020                           NaN           Italy     203591
# 168  4/29/2020                           NaN              UK     165221
# 57   4/29/2020                           NaN          France     165093
# ..         ...                           ...             ...        ...
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
#
#      Deaths  Recovered
# 265   23477          0
# 153   24275     132929
# 80    27682      71252
# ...

# %%
df.sort_values(by=['Confirmed'],ascending=False).head(50)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 265  4/29/2020       New York              US     299691   23477          0
# 153  4/29/2020            NaN           Spain     236899   24275     132929
# 80   4/29/2020            NaN           Italy     203591   27682      71252
# 168  4/29/2020            NaN              UK     165221   26097          0
# 57   4/29/2020            NaN          France     165093   24087      48228
# 61   4/29/2020            NaN         Germany     161539    6467     120400
# 167  4/29/2020            NaN          Turkey     117589    3081      44040
# 262  4/29/2020     New Jersey              US     116365    6771          0
# 134  4/29/2020            NaN          Russia      99399     972      10286
# 76   4/29/2020            NaN            Iran      93657    5957      73791
# 22   4/29/2020            NaN          Brazil      79685    5513      34132
# ...
